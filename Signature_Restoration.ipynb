# %%
from torchsummary import summary

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
import gdown
# Replace 'file_id' with the actual file ID of the shared file
file_id = '1c-55gkJyv11ZttcGtb1bJc_oYmX_qARw'

# Define the destination path and file name
destination_path = '/content'
file_name = '1c-55gkJyv11ZttcGtb1bJc_oYmX_qARw.zip'

# Construct the download link
url = f'https://drive.google.com/uc?id={file_id}'

# Download the file
gdown.download(url, output=destination_path + '/' + file_name)

# %%
# !unzip '/content/gdrive/MyDrive/sign_dataset_for_restoration_cyclegan.zip' -d '/content'

# %%
# !unzip "/content/gdrive/MyDrive/restoration_result-20240413T072005Z-001.zip" -d "/content/gdrive/MyDrive"

# %%
# !pip install -r /content/pytorch-CycleGAN-and-pix2pix/requirements.txt

# %%
# !pip install visdom
# !pip install dominate

# %%
# !pip install -e

# %%
# !pip install git+https://github.com/fossasia/visdom

# %%
# !visdom

# %%
# !touch ~/.ssh/config

# %%
# !ssh -p 8097 #ip

# %%
# !touch ~/.ssh/config:  #ip

# %%
# !python -m visdom.server

# %%
import os

import tensorflow as tf
from tensorflow import keras

print(tf.version.VERSION)

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

train_labels = train_labels[:1000]
test_labels = test_labels[:1000]

train_images = train_images[:1000].reshape(-1, 28 * 28) / 255.0
test_images = test_images[:1000].reshape(-1, 28 * 28) / 255.0

# %%
checkpoint_path = "training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
# !unzip "/content/gdrive/MyDrive/res_data.zip" -d "/content"

# %%
# !python /content/pytorch-CycleGAN-and-pix2pix/train.py --dataroot /content/sign_dataset_for_restoration_cyclegan --name restoration_result_cyclegan --model cycle_gan --checkpoints_dir /content/gdrive/MyDrive/restoration_result_cyclegan  --continue_train --epoch_count 153

# %%
# !python /content/gdrive/MyDrive/cyclegancode/cyclegancode/pytorch-CycleGAN-and-pix2pix-master/train.py --dataroot /content/gan_signdata_kaggle/ --name gan_signdata_kaggle --model cycle_gan --checkpoints_dir /content/gdrive/MyDrive/res/  --continue_train --epoch_count 131

# %%
os.listdir(checkpoint_dir)

# %%
# !python test.py --dataroot datasets/gan_signdata_kaggle/testB --name gan_signdata_kaggle --model test --no_dropout

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cp ./checkpoints/gan_signdata_kaggle/latest_net_G_B.pth ./checkpoints/gan_signdata_kaggle/latest_net_G.pth
# !python test.py --dataroot datasets/gan_signdata_kaggle/testB --name gan_signdata_kaggle --model test --no_dropout
