# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !git clone https://github.com/amaljoseph/Signature-Verification_System_using_YOLOv5-and-CycleGAN.git

# %%
# !git clone  'https://github.com/ultralytics/yolov5.git'

# %%
# !sed -i 's/PyYAML>=5.3.1/PyYAML==5.4.1/g' /content/yolov5/requirements.txt
# %cd /content/yolov5
# !pip install -r requirements.txt

# %%
# !pip install "cython<3.0.0" && pip install --no-build-isolation pyyaml==5.4.1

# %%
##Importing Libraries

import shutil
import os, sys, random
from glob import glob
import pandas as pd
from shutil import copyfile
import pandas as pd
from sklearn import preprocessing, model_selection
import matplotlib.pyplot as plt
from matplotlib import patches
import numpy as np
import os
# %matplotlib inline


# !sed -i 's/nc: 80/nc: 2/g' /content/yolov5/models/yolov5x.yaml
# !cat /content/gdrive/MyDrive/tobacco_data.yaml

# %%
# !unzip "/content/gdrive/MyDrive/tobacco_yolo_format.zip" -d "/content/yolov5"

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !unzip "/content/gdrive/MyDrive/detection_result1-epoch285.zip" -d "/content"

# %%
##Training**
# !python /content/yolov5/train.py --img 640 --batch 16 --epochs 350 --single-cls \
    --data /content/gdrive/MyDrive/tobacco_data.yaml --cfg /content/yolov5/models/yolov5x.yaml --name toboco --resume /content/detection_result1/toboco2/weights/last.pt  --project /content/gdrive/MyDrive/detection_result1
# Out:
# 2024-01-08 15:19:16.601352: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-08 15:19:16.601408: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-08 15:19:16.603265: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python yolov5/train.py --data /content/Signature-Verification_System_using_YOLOv5-and-CycleGAN/Training/YOLOv5/tobacco_data.yaml --weights '/content/yolov5/yolov5/runs/train/Tobacco-run/weights/last.pt' --cfg yolov5s.yaml
# Out:
# 2023-12-25 11:22:42.418685: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-25 11:22:42.418742: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-25 11:22:42.420243: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# usage: train.py [-h] [--weights WEIGHTS] [--cfg CFG] [--data DATA] [--hyp HYP] [--epochs EPOCHS]
#                 [--batch-size BATCH_SIZE] [--imgsz IMGSZ] [--rect] [--resume [RESUME]] [--nosave]
#                 [--noval] [--noautoanchor] [--noplots] [--evolve [EVOLVE]] [--bucket BUCKET]
# ...

# %%
import gdown

file_id = '11GZTm93ZW6hloCYKA54qofct0EbaZUe1'

# Define the destination path and file name
destination_path = '/content/gdrive/MyDrive/all'
file_name = '11GZTm93ZW6hloCYKA54qofct0EbaZUe1.zip'

# Construct the download link
url = f'https://drive.google.com/uc?id={file_id}'

# %%
import shutil

# Specify the path of the folder you want to zip
folder_to_zip = '/content/gdrive/MyDrive/all/tobacco_yolo_format'  # Replace with the actual path of your folder

# Specify the name of the zip file you want to create
zip_filename = '/content/gdrive/MyDrive/all/tobacco_yolo_format'

# Create a zip archive of the specified folder
shutil.make_archive(zip_filename, 'zip', folder_to_zip)

# Print the path of the zip file
print(f"Zip file created: {zip_filename}")

# %%
# !unzip "/content/gdrive/MyDrive/labels.zip" -d "/content/sample_data\k"

# %%
##Testing**


#To predict images in a folder**

# !python /content/yolov5/detect.py --source /content/sample_data_k/images_jpg --weights '/content/gdrive/MyDrive/detection_result1/toboco2/weights/best.pt' \
 --hide-labels --hide-conf  --line-thickness 2 --save-txt --save-csv --save-conf --save-crop --visualize  --augment

##To pedict a single image**
# Out:
# Traceback (most recent call last):
#   File "/content/yolov5/detect.py", line 1, in <module>
#     @smart_inference_mode()
# NameError: name 'smart_inference_mode' is not defined

# %%
import shutil

# Specify the path of the folder you want to zip
folder_to_zip = '/content/yolov5/runs/detect/exp3'  # Replace with the actual path of your folder

# Specify the name of the zip file you want to create
zip_filename = '/content/gdrive/MyDrive/exp3'

# Create a zip archive of the specified folder
shutil.make_archive(zip_filename, 'zip', folder_to_zip)

# Print the path of the zip file
print(f"Zip file created: {zip_filename}")
# Out:
# Zip file created: /content/gdrive/MyDrive/exp3
